# %%
pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in c:\users\admin\anaconda3\lib\site-packages (1.26.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
nlp=spacy.load("en_core_web_sm")
text="You are selected for the next round.Congrats you won the Match."
my_doc=nlp(text)
doc=nlp(text)
print([token.text for token in doc])
sentences=list(doc.sents)
print("Length of sentences:",len(sentences))
for sentence in sentences:
    print(sentence)
# Out:
# ['You', 'are', 'selected', 'for', 'the', 'next', 'round', '.', 'Congrats', 'you', 'won', 'the', 'Match', '.']
# Length of sentences: 2
# You are selected for the next round.
# Congrats you won the Match.

# %%
import fitz
from nltk.tokenize import sent_tokenize,word_tokenize
def pdf_to_text(pdf_path)
    doc=fitz.open(pdf_path)
    text=""
    for page in doc:
        text+=page.get_text('E:\book.pdf')
        print(pdf_text)
        
        wordpdf=word_tokenize(pdf_text)
        pharsepdf=sent_tokenize(pdf_text)
        print(wordpdf)
        print
        print(pharsepdf)
# Out:
#   Input In [3]
#     def pdf_to_text(pdf_path)
#                              ^
# SyntaxError: invalid syntax
